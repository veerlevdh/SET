# %%
import Kaart_class as kar
import pygame
import random
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def maak_dek(): #maak alle mogelijke kaarten en returned deze in willekeurige volgorde
    dek = [] #81 kaarten in een set dek
    for aantal in [-1,0,1]:
        for kleur in [-1,0,1]:
            for vulling in [-1,0,1]:
                for vorm in [-1,0,1]:
                    dek.append(kar.kaart(aantal, kleur, vulling, vorm))
    random.shuffle(dek)
    return dek

def set_of_niet(first, second, third): #bepaalt of een set voldoet of niet
    if first + second == third.vector:
        return True
    else:
        return False
    
def alle_sets_vinden(dek): #geeft alle sets uit een verzameling kaarten terug
    gevonden_sets=[]
    for i in range(0,10): 
        for j in range(i+1,11):
            first = dek[i]
            second = dek[j]
            for k in range(j+1, 12):
                third = dek[k]
                if set_of_niet(first, second, third):
                    gevonden_sets.append([i,j,k])
    return "lijsten met indexen gevonden sets" , gevonden_sets 

def computer_set(gevonden_sets): # geeft een willekeurige set terug uit de lijst met gevonden sets
    gekozen_set_index = random.randint(0,len(gevonden_sets)-1)
    return gevonden_sets[gekozen_set_index]

def print_gedeeld(gedeeld):# drukt alle kaarten in gedeeld af
    for i in range(0,12):
        print(gedeeld[i])

def eerste_keer_delen(dek):#pakt de laatste twaalf kaarten uit de lijst. 
    gedeeld=[]
    for i in range(0,12):
        gedeeld.append(dek.pop()) #verwijder kaarten uit dek en voeg toe aan uitgedeelde kaart
    return gedeeld

# %%
def set_aanwijzen(gedeeld, eerste, tweede, derde):
    mogelijke_sets = alle_sets_vinden(gedeeld)
    if [int(eerste)-1,int(tweede)-1, int(derde)-1] in mogelijke_sets:
        return True
    else:
        return False
    
def set_vervangen(gedeeld, eerste, tweede, derde, dek):
    del gedeeld[int(derde)-1]
    del gedeeld[int(tweede)-1]
    del gedeeld[int(eerste)-1]
    gedeeld.append(dek.pop)
    gedeeld.append(dek.pop)
    gedeeld.append(dek.pop)
    return gedeeld

def computer_set(gevonden_sets):
    gekozen_set_index = random.randint(0,len(gevonden_sets)-1)
    return gevonden_sets[gekozen_set_index]
    print(computer_set(D))

# %%
def run_set():
    dek = maak_dek()
    for i in range(81):
        print(dek[i])
    gedeeld = eerste_keer_delen(dek)
    while len(dek)>0:
        print(alle_sets_vinden(gedeeld))
        print_gedeeld(deki)
        eerste, tweede, derde = input("vul set in").split()
        if set_aanwijzen(gedeeld, eerste, tweede, derde) is True:
            print("klopt")
            print(dek)
            set_vervangen(gedeeld, eerste, tweede, derde, dek)
        else:
            print("dat is geen set")
run_set()
# Out:
# greenovalshaded3
# purplediamondshaded3
# redsquigglefilled3
# purplesquigglefilled1
# purplesquiggleshaded3
# redsquiggleshaded2
# greenovalfilled1
# redsquiggleempty2
# greenovalfilled2
# greendiamondshaded2
# purplesquiggleempty1
# greensquiggleshaded3
# greenovalempty3
# redsquiggleempty1
# greendiamondshaded3
# purpleovalshaded2
# reddiamondfilled3
# greensquiggleempty3
# purplesquiggleempty3
# greensquigglefilled2
# redsquigglefilled1
# greenovalfilled3
# reddiamondempty2
# reddiamondshaded1
# greenovalempty2
# greensquigglefilled1
# redsquigglefilled2
# greendiamondshaded1
# purplediamondshaded1
# redovalshaded2
# greensquiggleempty2
# greensquiggleempty1
# greendiamondempty1
# greensquiggleshaded1
# purpleovalfilled1
# greendiamondempty3
# reddiamondfilled2
# purplesquiggleshaded1
# purpleovalfilled3
# purpleovalempty1
# greensquiggleshaded2
# purplediamondfilled3
# greensquigglefilled3
# reddiamondempty1
# reddiamondfilled1
# greendiamondfilled1
# redovalshaded1
# redsquiggleshaded3
# redovalempty1
# redsquiggleempty3
# redovalshaded3
# purpleovalempty3
# purplesquigglefilled2
# redovalfilled1
# redsquiggleshaded1
# greenovalempty1
# purplediamondempty1
# reddiamondshaded2
# purpleovalshaded3
# purplesquiggleshaded2
# greendiamondempty2
# redovalfilled2
# redovalempty3
# purplediamondempty3
# purplediamondempty2
# reddiamondempty3
# purpleovalempty2
# purplediamondshaded2
# redovalempty2
# greendiamondfilled2
# purplediamondfilled2
# purpleovalfilled2
# greendiamondfilled3
# purplesquigglefilled3
# purpleovalshaded1
# purplediamondfilled1
# purplesquiggleempty2
# greenovalshaded1
# redovalfilled3
# reddiamondshaded3
# greenovalshaded2
# ('lijsten met indexen gevonden sets', [[2, 7, 8], [5, 7, 9]])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-84ab1b06ea56> in <module>
#      14         else:
#      15             print("dat is geen set")
# ---> 16 run_set()
#
# <ipython-input-5-84ab1b06ea56> in run_set()
#       6     while len(dek)>0:
#       7         print(alle_sets_vinden(gedeeld))
# ----> 8         print_gedeeld(deki)
#       9         eerste, tweede, derde = input("vul set in").split()
#      10         if set_aanwijzen(gedeeld, eerste, tweede, derde) is True:
#
# NameError: name 'deki' is not defined

# %%
print(d)
